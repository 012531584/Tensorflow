# %%
import pandas as pd
import numpy as np
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPool2D, AvgPool2D, Flatten, BatchNormalization, Activation
from keras.callbacks import LearningRateScheduler
import tensorflow as tf
from os import listdir
import matplotlib.pyplot as plt
from tensorflow.keras.backend import clear_session
from random import seed, randint
import time
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
class model():
    def __init__(self, input_shape, mode, kernel_size):
        self.input_shape = input_shape
        self.mode = mode
        self.kernel_size = kernel_size
        if mode == 'v1':
            self.model = self.create_model_original()
            self.model.compile(optimizer='adam',
                                loss='categorical_crossentropy',
                                metrics=['accuracy'])
        else:
            if mode == 'v2':
                self.model = self.create_model_student(pruning = 0)
            elif mode == 'v2_p50':
                self.model = self.create_model_student(pruning = 50)
            elif mode == 'v2_p70':
                self.model = self.create_model_student(pruning = 70)
            self.model.compile(optimizer='adam',
                                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                                metrics=['accuracy'])        
            
    # Kaggle original model
    def create_model_original(self):
        model = Sequential(name = self.mode)
        model.add(Conv2D(32, kernel_size=self.kernel_size, padding='same', activation='relu', input_shape=self.input_shape))
        model.add(MaxPool2D(pool_size=2))
        model.add(Flatten())
        model.add(Dense(500, activation='relu'))
        model.add(Dense(43, activation='softmax'))
        return model

    # Paper's student model
    def create_model_student(self, pruning):
        if pruning == 0:
            filters_num = [64, 64, 128, 128, 256]
        elif pruning == 50:
            filters_num = [32, 32, 64, 64, 128]
        else:
            filters_num = [21, 54, 44, 29, 43] 

        model = Sequential(name = self.mode)
        model.add(Conv2D(filters_num[0], (3, 3), strides=(1,1), padding= 'SAME', input_shape = self.input_shape)) # output 32*32
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(Conv2D(filters_num[1], (3, 3), strides=(1,1), padding= 'SAME')) # output 32*32
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPool2D(pool_size=(2,2), strides = (2,2), padding='VALID' )) #  output 16*16

        model.add(Conv2D(filters_num[2], (3, 3), strides=(1,1),  padding= 'SAME')) # output 16*16
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(Conv2D(filters_num[3], (3, 3), strides=(1,1), padding= 'SAME')) # output 16*16
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPool2D(pool_size=(2,2), strides = (2,2), padding= 'VALID')) #  output 8*8

        model.add(Conv2D(filters_num[4], (3, 3), strides=(1,1), padding= 'SAME')) # output 8*8
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(AvgPool2D(pool_size=(2,2), strides = (2,2), padding= 'VALID')) #  output 4*4
        model.add(Flatten()) # output - 4096
        model.add(Dense(43)) # 43 classes of output labels
        return model

    def train(self, X_train, Y_train, epochs, batch_size, validation_data, callbacks=False):
        if self.mode == 'v1':
            self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=validation_data, callbacks=[callbacks])
        else:
            self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=validation_data)        

    def accuracy(self, x, y):
        results = self.model.evaluate(x, y)
        print(self.mode, 'test loss, test acc:', results)
        return results
    def get_predict(self, x):
        return self.model.predict(x)

# %%
class model_v2():
    def __init__(self, dataset, mode, epochs, batch_size, kernel_size, callbacks=None):
        self.mode, self.kernel_size = mode, kernel_size
        (X_train, Y_train, X_val, Y_val, X_test, Y_test) = dataset
        self.input_shape = X_train.shape[1:]
        if mode == 'v1':
            self.model = self.create_model_original()
            self.model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
            self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(X_val, Y_val), callbacks=[callbacks])
        else:
            if mode == 'v2':
                self.model, self.pruning = self.create_model_student(), 0
            elif mode == 'v2_p50':
                self.model, self.pruning = self.create_model_student(), 50
            else:
                self.model, self.pruning = self.create_model_student(), 70
            self.model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), metrics=['accuracy']) 
            self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(X_val, Y_val))

        [_, self.acc] = self.model.evaluate(X_test, Y_test, batch_size)
    
    # Kaggle original model
    def create_model_original(self):
        model = Sequential(name = self.mode)
        model.add(Conv2D(32, kernel_size=self.kernel_size, padding='same', activation='relu', input_shape=self.input_shape))
        model.add(MaxPool2D(pool_size=2))
        model.add(Flatten())
        model.add(Dense(500, activation='relu'))
        model.add(Dense(43, activation='softmax'))
        return model

    # Paper's student model
    def create_model_student(self):
        if self.pruning == 0:
            filters_num = [64, 64, 128, 128, 256]
        elif self.pruning == 50:
            filters_num = [32, 32, 64, 64, 128]
        else:
            filters_num = [21, 54, 44, 29, 43] 

        model = Sequential(name = self.mode)
        model.add(Conv2D(filters_num[0], (3, 3), strides=(1,1), padding= 'SAME', input_shape = self.input_shape)) # output 32*32
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(Conv2D(filters_num[1], (3, 3), strides=(1,1), padding= 'SAME')) # output 32*32
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPool2D(pool_size=(2,2), strides = (2,2), padding='VALID' )) #  output 16*16

        model.add(Conv2D(filters_num[2], (3, 3), strides=(1,1),  padding= 'SAME')) # output 16*16
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(Conv2D(filters_num[3], (3, 3), strides=(1,1), padding= 'SAME')) # output 16*16
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPool2D(pool_size=(2,2), strides = (2,2), padding= 'VALID')) #  output 8*8

        model.add(Conv2D(filters_num[4], (3, 3), strides=(1,1), padding= 'SAME')) # output 8*8
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(AvgPool2D(pool_size=(2,2), strides = (2,2), padding= 'VALID')) #  output 4*4
        model.add(Flatten()) # output - 4096
        model.add(Dense(43)) # 43 classes of output labels
        return model      

    def get_accuracy(self):
        print(self.mode + ' kernel_size_' + str(self.kernel_size), 'test acc:', self.acc)
        return self.acc

    def get_predict(self, x):      
        return self.model.predict(x)

# %% [markdown]
# ### Kernel varience of the original model

# %%
# Models summary of diff. kernel sizes
# clear_session()
# filters = [3, 5, 9, 13, 15, 19, 23, 25, 31]
# # Create 9 models
# model = [0] * len(filters)
# for i in range(len(model)):
#     model[i] = Sequential()
#     model[i].add(Conv2D(32, kernel_size=filters[i], padding='same', activation='relu', input_shape=(32, 32, 3)))
#     model[i].add(MaxPool2D(pool_size=2))
#     model[i].add(Flatten())
#     model[i].add(Dense(500, activation='relu'))
#     model[i].add(Dense(43, activation='softmax'))
#     model[i].compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#     model[i].summary()

# %%
def get_preprocessed_data(path):
    # Load data
    data = pd.read_pickle(path)
    (X_train, Y_train, X_val, Y_val, X_test, Y_test) = (data['x_train'], data['y_train'], data['x_validation'], 
                                                        data['y_validation'], data['x_test'], data['y_test']) 
    # Reshape the X_data & encode Y_data
    X_train = np.transpose(X_train, (0, 2, 3, 1))
    X_val = np.transpose(X_val, (0, 2, 3, 1))
    X_test = np.transpose(X_test, (0, 2, 3, 1))

    Y_train = to_categorical(Y_train, num_classes=43)
    Y_val = to_categorical(Y_val, num_classes=43)
    Y_test = to_categorical(Y_test, num_classes=43)
    print('X_train.shape:', X_train.shape, ' X_val.shape:', X_val.shape, ' X_test.shape:', X_test.shape, 
          ' Y_train.shape:', Y_train.shape, ' Y_val.shape:', Y_val.shape, ' Y_test.shape:', Y_test.shape)
    return X_train, Y_train, X_val, Y_val, X_test, Y_test

def plot_result(filters, model_accuracies, model_times):
    legend = []   # Convert filter size name from int to str
    for filter_size in filters:
        legend.append(str(filter_size))
    plt.rcParams['figure.figsize'] = (15.0, 15.0) # Setting default size of plots
    plt.rcParams['image.interpolation'] = 'nearest'
    fig = plt.figure()
    # Plot accuracies
    plt.subplot(2, 1, 1)
    for i in range(len(model_accuracies)):
        plt.plot(model_accuracies[i], '-o', linewidth=0.5)
    plt.title('Accuracy of Models', fontsize=22)
    plt.legend(legend, loc='lower right', fontsize='x-large')
    plt.xlabel('Data File Number', fontsize=20)
    plt.ylabel('Accuracy of Testing Data', fontsize=20)
    plt.yscale('linear')
    plt.tick_params(labelsize=18)
    # Plot operation times
    plt.subplot(2, 1, 2)
    for i in range(len(model_times)):
        plt.plot(model_times[i], '-o', linewidth=0.5)
    plt.title('Training Time of Models', fontsize=22)
    plt.legend(legend, loc='lower right', fontsize='x-large')
    plt.xlabel('Data File Number', fontsize=20)
    plt.ylabel('Training Time', fontsize=20)
    plt.yscale('linear')
    plt.tick_params(labelsize=18)
    plt.show()

def create_model_original(input_shape, kernel_size):
    model = Sequential(name = 'org_model')
    model.add(Conv2D(32, kernel_size=kernel_size, padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPool2D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(500, activation='relu'))
    model.add(Dense(43, activation='softmax'))
    return model

def kernel_test():
    clear_session()
    path = 'drive/Shared drives/258/data/preprocessed/'
    model_v1_accuracies = np.zeros(shape = (9, 9))  # 9 files, 9 models
    model_v1_times = np.zeros(shape = (9, 9)) 
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** (x + 5))    # epochs=5
    filters = [3, 5, 9, 13, 15, 19, 23, 25, 31]
    models = [0] * len(filters)
    file_number = 0
    # Traverse 9 files
    for filename in sorted(listdir(path)):
        print('==================================================================================================')
        print('File: ', filename)
        X_train, Y_train, X_val, Y_val, X_test, Y_test = get_preprocessed_data(path+filename)

        # Create & train models of diff. kernel sizes
        for i in range(len(models)):
            start_time = time.time()
            models[i] = create_model_original(input_shape=X_train.shape[1:], kernel_size=filters[i])
            models[i].compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])            
            models[i].fit(X_train, Y_train, epochs=5, batch_size=32, verbose=0, validation_data=(X_val, Y_val), callbacks=[annealer])
            [_, acc] = models[i].evaluate(X_test, Y_test, batch_size=32)
            run_time = time.time() - start_time
            print('kernel_size: %s     acc:%s     %s seconds' % (filters[i], acc, run_time))
            model_v1_accuracies[i][file_number], model_v1_times[i][file_number] = acc, run_time
        file_number+=1
    return model_v1_accuracies, model_v1_times

# %%
model_v1_accuracies, model_v1_times = kernel_test()
# Out:
# ==================================================================================================
# File:  data0.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 82us/step
# kernel_size: 3     acc:0.8365795612335205     83.71910095214844 seconds
# 12630/12630 [==============================] - 1s 85us/step
# kernel_size: 5     acc:0.8298495411872864     83.93075799942017 seconds
# 12630/12630 [==============================] - 1s 93us/step
# kernel_size: 9     acc:0.7833729386329651     87.74437117576599 seconds
# 12630/12630 [==============================] - 1s 93us/step
# kernel_size: 13     acc:0.6111639142036438     90.23081254959106 seconds
# 12630/12630 [==============================] - 1s 88us/step
# kernel_size: 15     acc:0.13079968094825745     94.1544783115387 seconds
# 12630/12630 [==============================] - 1s 91us/step
# kernel_size: 19     acc:0.030878860503435135     94.1328797340393 seconds
# 12630/12630 [==============================] - 1s 95us/step
# kernel_size: 23     acc:0.03800475224852562     94.93095064163208 seconds
# 12630/12630 [==============================] - 1s 93us/step
# kernel_size: 25     acc:0.03325415775179863     93.94713735580444 seconds
# 12630/12630 [==============================] - 1s 95us/step
# kernel_size: 31     acc:0.021377671509981155     93.82399773597717 seconds
# ==================================================================================================
# File:  data1.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 80us/step
# kernel_size: 3     acc:0.8934283256530762     85.15303611755371 seconds
# 12630/12630 [==============================] - 1s 85us/step
# kernel_size: 5     acc:0.8932700157165527     85.30944275856018 seconds
# 12630/12630 [==============================] - 1s 90us/step
# kernel_size: 9     acc:0.8815518617630005     88.65243363380432 seconds
# 12630/12630 [==============================] - 1s 92us/step
# kernel_size: 13     acc:0.8673792481422424     90.82437682151794 seconds
# 12630/12630 [==============================] - 1s 92us/step
# kernel_size: 15     acc:0.8646872639656067     95.08691596984863 seconds
# 12630/12630 [==============================] - 1s 89us/step
# kernel_size: 19     acc:0.8783847689628601     94.87908983230591 seconds
# 12630/12630 [==============================] - 1s 89us/step
# kernel_size: 23     acc:0.8513064384460449     94.62646389007568 seconds
# 12630/12630 [==============================] - 1s 86us/step
# kernel_size: 25     acc:0.8530483245849609     94.40882110595703 seconds
# 12630/12630 [==============================] - 1s 90us/step
# kernel_size: 31     acc:0.8345209956169128     95.41874098777771 seconds
# ==================================================================================================
# File:  data2.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 82us/step
# kernel_size: 3     acc:0.8763262033462524     82.86495065689087 seconds
# 12630/12630 [==============================] - 1s 86us/step
# kernel_size: 5     acc:0.8855106830596924     84.68387246131897 seconds
# 12630/12630 [==============================] - 1s 91us/step
# kernel_size: 9     acc:0.8898653984069824     88.51014280319214 seconds
# 12630/12630 [==============================] - 1s 87us/step
# kernel_size: 13     acc:0.8863024711608887     90.65736150741577 seconds
# 12630/12630 [==============================] - 1s 89us/step
# kernel_size: 15     acc:0.8682501912117004     94.55229306221008 seconds
# 12630/12630 [==============================] - 1s 92us/step
# kernel_size: 19     acc:0.850197970867157     94.83603191375732 seconds
# 12630/12630 [==============================] - 1s 91us/step
# kernel_size: 23     acc:0.8527315855026245     94.6190824508667 seconds
# 12630/12630 [==============================] - 1s 88us/step
# kernel_size: 25     acc:0.8557403087615967     94.64894556999207 seconds
# 12630/12630 [==============================] - 1s 91us/step
# kernel_size: 31     acc:0.8540775775909424     95.60714411735535 seconds
# ==================================================================================================
# File:  data3.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 83us/step
# kernel_size: 3     acc:0.8794140815734863     83.28541994094849 seconds
# 12630/12630 [==============================] - 1s 84us/step
# kernel_size: 5     acc:0.8855898380279541     84.45075249671936 seconds
# 12630/12630 [==============================] - 1s 89us/step
# kernel_size: 9     acc:0.8828186988830566     88.01135778427124 seconds
# 12630/12630 [==============================] - 1s 88us/step
# kernel_size: 13     acc:0.8872525691986084     90.37917184829712 seconds
# 12630/12630 [==============================] - 1s 90us/step
# kernel_size: 15     acc:0.8606492280960083     94.08485174179077 seconds
# 12630/12630 [==============================] - 1s 96us/step
# kernel_size: 19     acc:0.8295328617095947     94.83700966835022 seconds
# 12630/12630 [==============================] - 1s 91us/step
# kernel_size: 23     acc:0.8333333134651184     94.36348938941956 seconds
# 12630/12630 [==============================] - 1s 89us/step
# kernel_size: 25     acc:0.8383214473724365     93.43275332450867 seconds
# 12630/12630 [==============================] - 1s 91us/step
# kernel_size: 31     acc:0.8439429998397827     94.64332866668701 seconds
# ==================================================================================================
# File:  data4.pickle
# X_train.shape: (86989, 32, 32, 1)  X_val.shape: (4410, 32, 32, 1)  X_test.shape: (12630, 32, 32, 1)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 65us/step
# kernel_size: 3     acc:0.8688836097717285     77.98635268211365 seconds
# 12630/12630 [==============================] - 1s 67us/step
# kernel_size: 5     acc:0.8494061827659607     76.75249123573303 seconds
# 12630/12630 [==============================] - 1s 68us/step
# kernel_size: 9     acc:0.8086302280426025     79.33869624137878 seconds
# 12630/12630 [==============================] - 1s 75us/step
# kernel_size: 13     acc:0.8380839228630066     81.00207138061523 seconds
# 12630/12630 [==============================] - 1s 75us/step
# kernel_size: 15     acc:0.7475059628486633     82.4909553527832 seconds
# 12630/12630 [==============================] - 1s 73us/step
# kernel_size: 19     acc:0.8254948258399963     83.39402174949646 seconds
# 12630/12630 [==============================] - 1s 75us/step
# kernel_size: 23     acc:0.021377671509981155     87.50964975357056 seconds
# 12630/12630 [==============================] - 1s 76us/step
# kernel_size: 25     acc:0.021377671509981155     88.39450001716614 seconds
# 12630/12630 [==============================] - 1s 77us/step
# kernel_size: 31     acc:0.0047505940310657024     88.32828998565674 seconds
# ==================================================================================================
# File:  data5.pickle
# X_train.shape: (86989, 32, 32, 1)  X_val.shape: (4410, 32, 32, 1)  X_test.shape: (12630, 32, 32, 1)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 62us/step
# kernel_size: 3     acc:0.9016627073287964     76.32075476646423 seconds
# 12630/12630 [==============================] - 1s 63us/step
# kernel_size: 5     acc:0.9026128053665161     76.41347861289978 seconds
# 12630/12630 [==============================] - 1s 66us/step
# kernel_size: 9     acc:0.848456084728241     78.48876571655273 seconds
# 12630/12630 [==============================] - 1s 68us/step
# kernel_size: 13     acc:0.8431512117385864     79.54351758956909 seconds
# 12630/12630 [==============================] - 1s 71us/step
# kernel_size: 15     acc:0.8399049639701843     81.54286217689514 seconds
# 12630/12630 [==============================] - 1s 73us/step
# kernel_size: 19     acc:0.8687252402305603     82.6714494228363 seconds
# 12630/12630 [==============================] - 1s 73us/step
# kernel_size: 23     acc:0.011876484379172325     86.9665756225586 seconds
# 12630/12630 [==============================] - 1s 72us/step
# kernel_size: 25     acc:0.8523356914520264     87.45577931404114 seconds
# 12630/12630 [==============================] - 1s 71us/step
# kernel_size: 31     acc:0.00712589081376791     87.17127847671509 seconds
# ==================================================================================================
# File:  data6.pickle
# X_train.shape: (86989, 32, 32, 1)  X_val.shape: (4410, 32, 32, 1)  X_test.shape: (12630, 32, 32, 1)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 65us/step
# kernel_size: 3     acc:0.920110821723938     78.29382562637329 seconds
# 12630/12630 [==============================] - 1s 63us/step
# kernel_size: 5     acc:0.9326207637786865     77.330491065979 seconds
# 12630/12630 [==============================] - 1s 67us/step
# kernel_size: 9     acc:0.9352335929870605     78.6863739490509 seconds
# 12630/12630 [==============================] - 1s 68us/step
# kernel_size: 13     acc:0.9193982481956482     79.82817721366882 seconds
# 12630/12630 [==============================] - 1s 69us/step
# kernel_size: 15     acc:0.9079968333244324     81.73293900489807 seconds
# 12630/12630 [==============================] - 1s 71us/step
# kernel_size: 19     acc:0.8894695043563843     82.34754276275635 seconds
# 12630/12630 [==============================] - 1s 72us/step
# kernel_size: 23     acc:0.9086302518844604     87.1482720375061 seconds
# 12630/12630 [==============================] - 1s 72us/step
# kernel_size: 25     acc:0.8993666172027588     86.06999063491821 seconds
# 12630/12630 [==============================] - 1s 70us/step
# kernel_size: 31     acc:0.911797285079956     87.1284728050232 seconds
# ==================================================================================================
# File:  data7.pickle
# X_train.shape: (86989, 32, 32, 1)  X_val.shape: (4410, 32, 32, 1)  X_test.shape: (12630, 32, 32, 1)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 63us/step
# kernel_size: 3     acc:0.9108471870422363     76.68988060951233 seconds
# 12630/12630 [==============================] - 1s 64us/step
# kernel_size: 5     acc:0.9256532192230225     75.8172059059143 seconds
# 12630/12630 [==============================] - 1s 66us/step
# kernel_size: 9     acc:0.9262866377830505     78.35613203048706 seconds
# 12630/12630 [==============================] - 1s 70us/step
# kernel_size: 13     acc:0.9226444959640503     79.9437837600708 seconds
# 12630/12630 [==============================] - 1s 72us/step
# kernel_size: 15     acc:0.9114806056022644     81.7567367553711 seconds
# 12630/12630 [==============================] - 1s 72us/step
# kernel_size: 19     acc:0.9153602719306946     83.41660666465759 seconds
# 12630/12630 [==============================] - 1s 75us/step
# kernel_size: 23     acc:0.925336480140686     87.37109613418579 seconds
# 12630/12630 [==============================] - 1s 71us/step
# kernel_size: 25     acc:0.9053840041160583     87.72371006011963 seconds
# 12630/12630 [==============================] - 1s 70us/step
# kernel_size: 31     acc:0.9103721380233765     86.20373058319092 seconds
# ==================================================================================================
# File:  data8.pickle
# X_train.shape: (86989, 32, 32, 1)  X_val.shape: (4410, 32, 32, 1)  X_test.shape: (12630, 32, 32, 1)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 63us/step
# kernel_size: 3     acc:0.9198732972145081     76.92627573013306 seconds
# 12630/12630 [==============================] - 1s 63us/step
# kernel_size: 5     acc:0.9392715692520142     76.80998635292053 seconds
# 12630/12630 [==============================] - 1s 66us/step
# kernel_size: 9     acc:0.9226444959640503     77.57703447341919 seconds
# 12630/12630 [==============================] - 1s 69us/step
# kernel_size: 13     acc:0.9118764996528625     79.23057985305786 seconds
# 12630/12630 [==============================] - 1s 71us/step
# kernel_size: 15     acc:0.9147268533706665     81.93165349960327 seconds
# 12630/12630 [==============================] - 1s 70us/step
# kernel_size: 19     acc:0.9050673246383667     82.84573411941528 seconds
# 12630/12630 [==============================] - 1s 71us/step
# kernel_size: 23     acc:0.9079968333244324     87.3524820804596 seconds
# 12630/12630 [==============================] - 1s 71us/step
# kernel_size: 25     acc:0.9032462239265442     86.6790189743042 seconds
# 12630/12630 [==============================] - 1s 72us/step
# kernel_size: 31     acc:0.8960411548614502     86.71181797981262 seconds

# %%
filters = [3, 5, 9, 13, 15, 19, 23, 25, 31]
plot_v1_acc(filters, model_v1_accuracies, model_v1_times)

# %% [markdown]
# ###Train & get the accuracies of four models (1 original model & 3 student models) in 9 files

# %%
def create_model_student(pruning, input_shape):
        if pruning == 0:
            filters_num = [64, 64, 128, 128, 256]
        elif pruning == 50:
            filters_num = [32, 32, 64, 64, 128]
        else:
            filters_num = [21, 54, 44, 29, 43] 

        model = Sequential()
        model.add(Conv2D(filters_num[0], (3, 3), strides=(1,1), padding= 'SAME', input_shape = input_shape)) # output 32*32
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(Conv2D(filters_num[1], (3, 3), strides=(1,1), padding= 'SAME')) # output 32*32
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPool2D(pool_size=(2,2), strides = (2,2), padding='VALID' )) #  output 16*16

        model.add(Conv2D(filters_num[2], (3, 3), strides=(1,1),  padding= 'SAME')) # output 16*16
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(Conv2D(filters_num[3], (3, 3), strides=(1,1), padding= 'SAME')) # output 16*16
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPool2D(pool_size=(2,2), strides = (2,2), padding= 'VALID')) #  output 8*8

        model.add(Conv2D(filters_num[4], (3, 3), strides=(1,1), padding= 'SAME')) # output 8*8
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(AvgPool2D(pool_size=(2,2), strides = (2,2), padding= 'VALID')) #  output 4*4
        model.add(Flatten()) # output - 4096
        model.add(Dense(43)) # 43 classes of output labels
        return model      

def test_models():
    clear_session()
    path = 'drive/Shared drives/258/data/preprocessed/'
    models_accuracy = np.zeros(shape = (4, 9))  # 4 models, 9 files
    models_times = np.zeros(shape = (4, 9)) 
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** (x + 5))    #epochs=5
    modes, file_number = ['v1', 'v2', 'v2_p50', 'v2_p70'], 0
    models = [0] * len(modes)
    # Traverse 9 files
    for filename in sorted(listdir(path)):
        print('==================================================================================================')
        print('File: ', filename)
        X_train, Y_train, X_val, Y_val, X_test, Y_test = get_preprocessed_data(path+filename)        

        for i in range(len(modes)):
            start_time = time.time()
            if modes[i] == 'v1':
                # Create original model
                models[i] = create_model_original(input_shape=X_train.shape[1:], kernel_size=3)
                models[i].compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 
                models[i].fit(X_train, Y_train, epochs=2, batch_size=128, verbose=0, validation_data=(X_val, Y_val), callbacks=[annealer])                
            else:
                # Create student model with diff. pruning
                if modes[i] == 'v2':
                    models[i] = create_model_student(pruning=0, input_shape=X_train.shape[1:])
                elif modes[i] == 'v2_p50':
                    models[i] = create_model_student(pruning=50, input_shape=X_train.shape[1:])
                else:
                    models[i] = create_model_student(pruning=70, input_shape=X_train.shape[1:])
                models[i].compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
                models[i].fit(X_train, Y_train, epochs=2, batch_size=128, verbose=0, validation_data=(X_val, Y_val))
            [_, acc] = models[i].evaluate(X_test, Y_test, batch_size=32)
            run_time = time.time() - start_time
            print('mode: %s     acc:%s     %s seconds' % (modes[i], acc, run_time))
            models_accuracy[i][file_number], models_times[i][file_number] = acc, run_time
        file_number+=1           
    return models_accuracy, models_times

# %%
models_accuracy, models_times = test_models()
# Out:
# ==================================================================================================
# File:  data0.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 84us/step
# mode: v1     acc:0.8037213087081909     16.55656933784485 seconds
# 12630/12630 [==============================] - 3s 251us/step
# mode: v2     acc:0.9691211581230164     111.69727683067322 seconds
# 12630/12630 [==============================] - 2s 164us/step
# mode: v2_p50     acc:0.9598574638366699     60.61599946022034 seconds
# 12630/12630 [==============================] - 2s 158us/step
# mode: v2_p70     acc:0.9441013336181641     57.48034715652466 seconds
# ==================================================================================================
# File:  data1.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c8f428fac6b2> in <module>()
# ----> 1 models_accuracy, models_times = test_models()
#
# <ipython-input-15-946c9433f03c> in test_models()
#      56                 models[i] = create_model_original(input_shape=X_train.shape[1:], kernel_size=3)
#      57                 models[i].compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# ---> 58                 models[i].fit(X_train, Y_train, epochs=2, batch_size=128, verbose=0, validation_data=(X_val, Y_val), callbacks=[annealer])
#      59             else:
#      60                 if modes[i] == 'v2':
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3798     return nest.pack_sequence_as(
#    3799         self._outputs_structure,
# -> 3800         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3801         expand_composites=True)
#    3802
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in <listcomp>(.0)
#    3798     return nest.pack_sequence_as(
#    3799         self._outputs_structure,
# -> 3800         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3801         expand_composites=True)
#    3802
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
accs = test_models_v2()
# Out:
# ===================================================================================================================================
# File:  data0.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 89us/step
# v1 test loss, test acc: [1.3976374041911448, 0.8157561421394348]
# model  0 file_num:  0 acc:  0.8157561421394348 run time:  16.88722848892212
# 12630/12630 [==============================] - 3s 253us/step
# v2 test loss, test acc: [0.23307399757896635, 0.9288202524185181]
# model  1 file_num:  0 acc:  0.9288202524185181 run time:  111.94178247451782
# 12630/12630 [==============================] - 2s 168us/step
# v2_p50 test loss, test acc: [0.13685131730690234, 0.9589073657989502]
# model  2 file_num:  0 acc:  0.9589073657989502 run time:  60.82972264289856
# 12630/12630 [==============================] - 2s 161us/step
# v2_p70 test loss, test acc: [0.17267263366509691, 0.9519398212432861]
# model  3 file_num:  0 acc:  0.9519398212432861 run time:  58.63595652580261
# ===================================================================================================================================
# File:  data1.pickle
# X_train.shape: (86989, 32, 32, 3)  X_val.shape: (4410, 32, 32, 3)  X_test.shape: (12630, 32, 32, 3)  Y_train.shape: (86989, 43)  Y_val.shape: (4410, 43)  Y_test.shape: (12630, 43)
# 12630/12630 [==============================] - 1s 89us/step
# v1 test loss, test acc: [0.7280548700904997, 0.8335708379745483]
# model  0 file_num:  1 acc:  0.8335708379745483 run time:  17.282312870025635
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-0467841e66d9> in <module>()
# ----> 1 accs = test_models_v2()
#
# <ipython-input-25-a4e12a81a123> in test_models_v2()
#      20                 model_tmp.train(X_train, Y_train, epchos_v1, batch_size_v1, validation_data=(X_val, Y_val), callbacks=annealer)
#      21             else:   # Student model
# ---> 22                 model_tmp.train(X_train, Y_train, epchos_v2, batch_size_v2, validation_data=(X_val, Y_val))
#      23             # Get the acc. of test data
#      24             [loss, acc] = model_tmp.accuracy(X_test, Y_test)
#
# <ipython-input-27-453e85393bfe> in train(self, X_train, Y_train, epochs, batch_size, validation_data, callbacks)
#      73             self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=validation_data, callbacks=[callbacks])
#      74         else:
# ---> 75             self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=validation_data)
#      76
#      77     def accuracy(self, x, y):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3798     return nest.pack_sequence_as(
#    3799         self._outputs_structure,
# -> 3800         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3801         expand_composites=True)
#    3802
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in <listcomp>(.0)
#    3798     return nest.pack_sequence_as(
#    3799         self._outputs_structure,
# -> 3800         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3801         expand_composites=True)
#    3802
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
def test_models_v2():
    clear_session()
    path = 'drive/Shared drives/258/data/preprocessed/'
    models_acc = np.zeros(shape = (4,9))   # 4 models, 9 files
    epchos_v1, epchos_v2, batch_size_v1,  batch_size_v2 = 2, 2, 128, 128
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** (x + epchos_v1))
    modes = ['v1', 'v2', 'v2_p50', 'v2_p70']
    file_num = 0
    for filename in sorted(listdir(path)):
        print('===================================================================================================================================')
        print('File: ', filename)
        # Get the data from path
        X_train, Y_train, X_val, Y_val, X_test, Y_test = get_preprocessed_data(path+filename)
        input_shape = X_train.shape[1:]     #(32,32,3) or (32,32,1)
        # Train the 4 models
        for i in range(len(modes)):
            start_time = time.time()
            model_tmp = model(input_shape, mode = modes[i], kernel_size = 3)
            if modes[i] == 'v1':  # Original model
                model_tmp.train(X_train, Y_train, epchos_v1, batch_size_v1, validation_data=(X_val, Y_val), callbacks=annealer)
            else:   # Student model
                model_tmp.train(X_train, Y_train, epchos_v2, batch_size_v2, validation_data=(X_val, Y_val))
            # Get the acc. of test data
            [loss, acc] = model_tmp.accuracy(X_test, Y_test)
            models_acc[i][file_num] = acc
            run_time = time.time() - start_time
            print('model ', i, 'file_num: ', file_num, 'acc: ', models_acc[i][file_num], 'run time: ', run_time)
        file_num+=1
    # Plot the accuracies
    return models_acc

def plot_acc(acc_array2D):
    plt.rcParams['figure.figsize'] = (15.0, 5.0) # Setting default size of plots
    plt.rcParams['image.interpolation'] = 'nearest'
    fig = plt.figure()
    # Plot the accuracies of the 4 models
    for i in range(acc_array2D.shape[0]):
        plt.plot(acc_array2D[i], '-o', linewidth=3.0)
    plt.title('Accuracy of models', fontsize=22)
    plt.legend(['original model', 'student model', 'student model 50% pruned', 'student model 70% pruned'], loc='lower right', fontsize='x-large')
    plt.xlabel('Data File Number', fontsize=20)
    plt.ylabel('Accuracy of Testing Data', fontsize=20)
    plt.tick_params(labelsize=18)
    # Showing the plot
    plt.show()

# %%
test_models()
# Out:
# ===================================================================================================================================
# File:  data0.pickle
# dict_keys(['x_test', 'y_validation', 'x_validation', 'labels', 'x_train', 'y_test', 'y_train'])
# (86989, 32, 32, 3) (4410, 32, 32, 3) (12630, 32, 32, 3) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 95us/step
# v1 test loss, test acc: [4.895119748314694, 0.8039588332176208]
# 12630/12630 [==============================] - 2s 178us/step
# v2 test loss, test acc: [0.11803452713814691, 0.9691211581230164]
# 12630/12630 [==============================] - 2s 156us/step
# v2_p50 test loss, test acc: [0.08808113166997926, 0.9790182113647461]
# 12630/12630 [==============================] - 2s 145us/step
# v2_p70 test loss, test acc: [0.30328512928748735, 0.931037187576294]
# ===================================================================================================================================
# File:  data1.pickle
# dict_keys(['x_train', 'y_test', 'x_test', 'x_validation', 'labels', 'y_train', 'y_validation'])
# (86989, 32, 32, 3) (4410, 32, 32, 3) (12630, 32, 32, 3) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 90us/step
# v1 test loss, test acc: [0.9679057768866809, 0.9001583456993103]
# 12630/12630 [==============================] - 2s 178us/step
# v2 test loss, test acc: [0.04862763016700514, 0.9867774844169617]
# 12630/12630 [==============================] - 2s 147us/step
# v2_p50 test loss, test acc: [0.08096399893002175, 0.9813935160636902]
# 12630/12630 [==============================] - 2s 140us/step
# v2_p70 test loss, test acc: [0.08698076342460379, 0.9777513742446899]
# ===================================================================================================================================
# File:  data2.pickle
# dict_keys(['y_test', 'y_validation', 'x_validation', 'x_train', 'y_train', 'labels', 'x_test'])
# (86989, 32, 32, 3) (4410, 32, 32, 3) (12630, 32, 32, 3) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 86us/step
# v1 test loss, test acc: [1.3026815992760121, 0.8593032360076904]
# 12630/12630 [==============================] - 2s 176us/step
# v2 test loss, test acc: [0.07168804143432364, 0.9796516299247742]
# 12630/12630 [==============================] - 2s 166us/step
# v2_p50 test loss, test acc: [0.33854792852128723, 0.9291369915008545]
# 12630/12630 [==============================] - 2s 148us/step
# v2_p70 test loss, test acc: [0.18703844639979988, 0.948060154914856]
# ===================================================================================================================================
# File:  data3.pickle
# dict_keys(['labels', 'y_validation', 'x_test', 'x_validation', 'x_train', 'y_test', 'y_train'])
# (86989, 32, 32, 3) (4410, 32, 32, 3) (12630, 32, 32, 3) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 91us/step
# v1 test loss, test acc: [1.26231863690055, 0.8735550045967102]
# 12630/12630 [==============================] - 2s 180us/step
# v2 test loss, test acc: [0.08029660346973023, 0.9813143014907837]
# 12630/12630 [==============================] - 2s 167us/step
# v2_p50 test loss, test acc: [0.08830725188824803, 0.9775930047035217]
# 12630/12630 [==============================] - 2s 159us/step
# v2_p70 test loss, test acc: [0.17069858973547197, 0.9566112160682678]
# ===================================================================================================================================
# File:  data4.pickle
# dict_keys(['y_validation', 'labels', 'x_validation', 'x_test', 'x_train', 'y_train', 'y_test'])
# (86989, 32, 32, 1) (4410, 32, 32, 1) (12630, 32, 32, 1) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 79us/step
# v1 test loss, test acc: [1.3371750920137901, 0.8258907198905945]
# 12630/12630 [==============================] - 2s 164us/step
# v2 test loss, test acc: [0.12743898172346219, 0.9755344390869141]
# 12630/12630 [==============================] - 2s 144us/step
# v2_p50 test loss, test acc: [0.16777712347454915, 0.9661124348640442]
# 12630/12630 [==============================] - 2s 134us/step
# v2_p70 test loss, test acc: [0.1550050086384014, 0.9665083289146423]
# ===================================================================================================================================
# File:  data5.pickle
# dict_keys(['x_test', 'y_test', 'x_train', 'y_train', 'x_validation', 'y_validation', 'labels'])
# (86989, 32, 32, 1) (4410, 32, 32, 1) (12630, 32, 32, 1) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 75us/step
# v1 test loss, test acc: [0.9913517347412363, 0.8677751421928406]
# 12630/12630 [==============================] - 2s 168us/step
# v2 test loss, test acc: [0.052275244706289116, 0.9866191744804382]
# 12630/12630 [==============================] - 2s 130us/step
# v2_p50 test loss, test acc: [0.05838309613354162, 0.9850356578826904]
# 12630/12630 [==============================] - 2s 129us/step
# v2_p70 test loss, test acc: [0.15945998319005852, 0.960490882396698]
# ===================================================================================================================================
# File:  data6.pickle
# dict_keys(['y_train', 'y_validation', 'y_test', 'labels', 'x_train', 'x_validation', 'x_test'])
# (86989, 32, 32, 1) (4410, 32, 32, 1) (12630, 32, 32, 1) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 71us/step
# v1 test loss, test acc: [0.5130236889265724, 0.9205067157745361]
# 12630/12630 [==============================] - 2s 161us/step
# v2 test loss, test acc: [0.1275229266539768, 0.9683293700218201]
# 12630/12630 [==============================] - 2s 135us/step
# v2_p50 test loss, test acc: [0.11738711246528964, 0.969437837600708]
# 12630/12630 [==============================] - 2s 136us/step
# v2_p70 test loss, test acc: [0.2979067442133456, 0.9332541823387146]
# ===================================================================================================================================
# File:  data7.pickle
# dict_keys(['x_train', 'y_test', 'x_validation', 'y_validation', 'labels', 'y_train', 'x_test'])
# (86989, 32, 32, 1) (4410, 32, 32, 1) (12630, 32, 32, 1) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 72us/step
# v1 test loss, test acc: [0.6265131954902439, 0.9216151833534241]
# 12630/12630 [==============================] - 2s 163us/step
# v2 test loss, test acc: [0.13945946088410305, 0.9712588787078857]
# 12630/12630 [==============================] - 2s 144us/step
# v2_p50 test loss, test acc: [0.07350958273207549, 0.9779097437858582]
# 12630/12630 [==============================] - 2s 132us/step
# v2_p70 test loss, test acc: [0.15065917022576406, 0.9590657353401184]
# ===================================================================================================================================
# File:  data8.pickle
# dict_keys(['y_validation', 'x_train', 'y_train', 'x_validation', 'labels', 'x_test', 'y_test'])
# (86989, 32, 32, 1) (4410, 32, 32, 1) (12630, 32, 32, 1) (86989, 43) (4410, 43) (12630, 43)
# 12630/12630 [==============================] - 1s 76us/step
# v1 test loss, test acc: [0.6968499473322664, 0.907442569732666]
# 12630/12630 [==============================] - 2s 173us/step
# v2 test loss, test acc: [0.28923012132240516, 0.9510688781738281]
# 12630/12630 [==============================] - 2s 132us/step
# v2_p50 test loss, test acc: [0.13761706345838878, 0.9644497036933899]
# 12630/12630 [==============================] - 2s 130us/step
# v2_p70 test loss, test acc: [0.1289429639404535, 0.9655581712722778]
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ###Some prediction of 70% pruned student model

# %%
# Load the data from "data1.pickle"
clear_session()
path = 'drive/Shared drives/258/data/preprocessed/'
filename = 'data1.pickle'
X_train, Y_train, X_val, Y_val, X_test, Y_test = get_preprocessed_data(path+filename)
# Out:
# dict_keys(['x_train', 'y_test', 'x_test', 'x_validation', 'labels', 'y_train', 'y_validation'])
# (86989, 32, 32, 3) (4410, 32, 32, 3) (12630, 32, 32, 3) (86989, 43) (4410, 43) (12630, 43)

# %%
# Train the 70% pruned student model
clear_session()
input_shape = X_train.shape[1:]
model_tmp = model(input_shape, mode = 'v2_p70', kernel_size = 3)
model_tmp.train(X_train, Y_train, 10, 128, validation_data=(X_val, Y_val))
result = model_tmp.accuracy(X_test, Y_test)
# Out:
# Train on 86989 samples, validate on 4410 samples
# Epoch 1/10
# 86989/86989 [==============================] - 29s 331us/step - loss: 0.6162 - accuracy: 0.8509 - val_loss: 0.2304 - val_accuracy: 0.9299
# Epoch 2/10
# 86989/86989 [==============================] - 20s 232us/step - loss: 0.0405 - accuracy: 0.9926 - val_loss: 0.2262 - val_accuracy: 0.9358
# Epoch 3/10
# 86989/86989 [==============================] - 21s 237us/step - loss: 0.0169 - accuracy: 0.9968 - val_loss: 0.1150 - val_accuracy: 0.9680
# Epoch 4/10
# 86989/86989 [==============================] - 21s 238us/step - loss: 0.0101 - accuracy: 0.9981 - val_loss: 0.0975 - val_accuracy: 0.9692
# Epoch 5/10
# 86989/86989 [==============================] - 21s 238us/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.1154 - val_accuracy: 0.9676
# Epoch 6/10
# 86989/86989 [==============================] - 20s 233us/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.0876 - val_accuracy: 0.9721
# Epoch 7/10
# 86989/86989 [==============================] - 21s 237us/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.1447 - val_accuracy: 0.9680
# Epoch 8/10
# 86989/86989 [==============================] - 20s 234us/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.1004 - val_accuracy: 0.9728
# Epoch 9/10
# 86989/86989 [==============================] - 21s 239us/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.8657 - val_accuracy: 0.8580
# Epoch 10/10
# 86989/86989 [==============================] - 20s 235us/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.0911 - val_accuracy: 0.9798
# 12630/12630 [==============================] - 2s 143us/step
# v2_p70 test loss, test acc: [0.13008690862805802, 0.9721298217773438]

# %%
# Get prediction from 10 random test images
def get_prediction(model, test_img, img_label, label_names):
    print("Real class: ", np.argmax(img_label))
    plt.imshow(test_img)
    plt.show()

    label = np.argmax(model.get_predict(test_img.reshape(-1,  32, 32, 3)), axis=1)[0]
    print("Predicted class: ", label)
    print("Sign Name: ", label_names['SignName'][label], '\n')

label_names = pd.read_csv('drive/Shared drives/258/data/label_names.csv')
seed(1)
for _ in range(10):
    val = randint(0, 43)
    get_prediction(model_tmp, X_test[val,:,:,:], Y_test[val], label_names)
    print("\n")
# Out:
# Real class:  25
# Predicted class:  25
# Sign Name:  Road work
#
#
#
# Real class:  12
# Predicted class:  12
# Sign Name:  Priority road
#
#
#
# Real class:  8
# Predicted class:  8
# Sign Name:  Speed limit (120km/h)
#
#
#
# Real class:  1
# Predicted class:  1
# Sign Name:  Speed limit (30km/h)
#
#
#
# Real class:  12
# Predicted class:  12
# Sign Name:  Priority road
#
#
#
# Real class:  38
# Predicted class:  38
# Sign Name:  Keep right
#
#
#
# Real class:  39
# Predicted class:  39
# Sign Name:  Keep left
#
#
#
# Real class:  38
# Predicted class:  38
# Sign Name:  Keep right
#
#
#
# Real class:  5
# Predicted class:  7
# Sign Name:  Speed limit (100km/h)
#
#
#
# Real class:  6
# Predicted class:  6
# Sign Name:  End of speed limit (80km/h)
