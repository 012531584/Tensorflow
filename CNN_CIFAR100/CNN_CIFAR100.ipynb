# %% [markdown]
# ### Load the training data from AWS s3

# %%
import pandas as pd
import boto3

bucket = "cmpe258-cifar-100"
file_name_x = "CIFAR_train_images.csv"
file_name_y = "CIFAR_train_labels.csv"

# 's3' is a key word. create connection to S3 using default config and all buckets within S3
s3 = boto3.client('s3') 

# Get object and file (key) from bucket
obj_x = s3.get_object(Bucket= bucket, Key= file_name_x) 
obj_y = s3.get_object(Bucket= bucket, Key= file_name_y) 


x_df = pd.read_csv(obj_x['Body']) # 'Body' is a key word
y_df = pd.read_csv(obj_y['Body'])

# %%
# Transfer label to one-hot format
y_df = pd.get_dummies(y_df.iloc[:, 0])

# %%
X_train = x_df.values
Y_train = y_df.values

# reshape the flatten array to (50000,32,32,3)
X_train = X_train.reshape((-1,3,32,32)).transpose([0,2,3,1])

X_train = X_train.astype('float32')

# Normalize images value from [0, 255] to [0, 1].
X_train = X_train / 255.

# %%
# Split the data to train & validation
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X_train, Y_train, test_size=0.2, shuffle = True)

# %% [markdown]
# ### Build the CNN model

# %%
from __future__ import print_function
import keras
#from keras.datasets import cifar100
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

import os
import pickle
import h5py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.

# %%
num_classes = 100
#save_dir = os.path.join(os.getcwd(), 'saved_models')
#model_name = 'cifar100.h5'

# %%
# Define loss function
from keras import backend as K
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
# Create Model
model = Sequential()

model.add(Conv2D(128, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), padding='same'))
model.add(Activation('elu'))
model.add(Conv2D(256, (3, 3)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3), padding='same'))
model.add(Activation('elu'))
model.add(Conv2D(512, (3, 3)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('elu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss=root_mean_squared_error,
              optimizer=opt,
              metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
# Run model and store test validated accuracy after each epoch.
epochs = 200
data_augmentation = True
num_predictions = 20
batch_size = 64
validations = []

for i in range(epochs):
    print('total epoch: ', i+1)
    if not data_augmentation:
        print('Not using data augmentation.')
        model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_data=(x_val, y_val),
                  shuffle=True)
    else:
        print('Using real-time data augmentation.')
        # This will do preprocessing and realtime data augmentation:
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)  # randomly flip images

        # Compute quantities required for feature-wise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)

        # Fit the model on the batches generated by datagen.flow().
        model.fit_generator(datagen.flow(x_train, y_train,
                                         batch_size=batch_size),
                            steps_per_epoch=x_train.shape[0] // batch_size,
                            epochs=1)#,
                            #validation_data=(x_val, y_val))
        validations.append(model.evaluate_generator(datagen.flow(x_val, y_val,
                                          batch_size=batch_size),
                                          steps=x_val.shape[0] // batch_size))
# Out:
# total epoch:  1
# Using real-time data augmentation.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/1
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 625/625 [==============================] - 111s 178ms/step - loss: 0.0989 - acc: 0.0618
# total epoch:  2
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0977 - acc: 0.1186
# total epoch:  3
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0965 - acc: 0.1578
# total epoch:  4
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0955 - acc: 0.1875
# total epoch:  5
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0945 - acc: 0.2181
# total epoch:  6
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0936 - acc: 0.2405
# total epoch:  7
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0927 - acc: 0.2606
# total epoch:  8
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0919 - acc: 0.2806
# total epoch:  9
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0912 - acc: 0.2969
# total epoch:  10
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0906 - acc: 0.3075
# total epoch:  11
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0901 - acc: 0.3174
# total epoch:  12
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0894 - acc: 0.3321
# total epoch:  13
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0890 - acc: 0.3405
# total epoch:  14
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0884 - acc: 0.3527
# total epoch:  15
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0878 - acc: 0.3629
# total epoch:  16
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0874 - acc: 0.3692
# total epoch:  17
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0869 - acc: 0.3821
# total epoch:  18
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0580 - acc: 0.7552
# total epoch:  153
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0578 - acc: 0.7574
# total epoch:  154
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0574 - acc: 0.7613
# total epoch:  155
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0575 - acc: 0.7598
# total epoch:  156
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0575 - acc: 0.7590
# total epoch:  157
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0572 - acc: 0.7617
# total epoch:  158
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0571 - acc: 0.7621
# total epoch:  159
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0570 - acc: 0.7625
# total epoch:  160
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0571 - acc: 0.7631
# total epoch:  161
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0570 - acc: 0.7628
# total epoch:  162
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0568 - acc: 0.7654
# total epoch:  163
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0567 - acc: 0.7651
# total epoch:  164
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0567 - acc: 0.7665
# total epoch:  165
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0567 - acc: 0.7675
# total epoch:  166
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0562 - acc: 0.7713
# total epoch:  167
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0562 - acc: 0.7709
# total epoch:  168
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0562 - acc: 0.7706
# total epoch:  169
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0560 - acc: 0.7732
# total epoch:  170
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0557 - acc: 0.7748
# total epoch:  171
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0557 - acc: 0.7742
# total epoch:  172
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0560 - acc: 0.7727
# total epoch:  173
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0557 - acc: 0.7746
# total epoch:  174
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0557 - acc: 0.7768
# total epoch:  175
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0551 - acc: 0.7812
# total epoch:  176
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0555 - acc: 0.7762
# total epoch:  177
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0555 - acc: 0.7785
# total epoch:  178
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0553 - acc: 0.7800
# total epoch:  179
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0553 - acc: 0.7800
# total epoch:  180
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0551 - acc: 0.7799
# total epoch:  181
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0549 - acc: 0.7830
# total epoch:  182
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0551 - acc: 0.7818
# total epoch:  183
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0548 - acc: 0.7836
# total epoch:  184
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0543 - acc: 0.7872
# total epoch:  185
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0546 - acc: 0.7863
# total epoch:  186
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0541 - acc: 0.7898
# total epoch:  187
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0540 - acc: 0.7899
# total epoch:  188
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0541 - acc: 0.7887
# total epoch:  189
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0541 - acc: 0.7902
# total epoch:  190
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 74ms/step - loss: 0.0539 - acc: 0.7924
# total epoch:  191
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0537 - acc: 0.7933
# total epoch:  192
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0540 - acc: 0.7918
# total epoch:  193
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0537 - acc: 0.7940
# total epoch:  194
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0541 - acc: 0.7916
# total epoch:  195
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0535 - acc: 0.7954
# total epoch:  196
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0536 - acc: 0.7937
# total epoch:  197
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0538 - acc: 0.7916
# total epoch:  198
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0534 - acc: 0.7967
# total epoch:  199
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0535 - acc: 0.7962
# total epoch:  200
# Using real-time data augmentation.
# Epoch 1/1
# 625/625 [==============================] - 46s 73ms/step - loss: 0.0531 - acc: 0.7976

# %%
# Save the validations result
pickle.dump(validations, open("loss_validation_v2.p",'wb'))

# Save the model
filename = 'cifar100_cnn_v2.sav'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ### Predict test data

# %%
# Load the test data
file_name_x_test = "CIFAR_test_images.csv"
obj_x_test = s3.get_object(Bucket= bucket, Key= file_name_x_test) 
x_test_df = pd.read_csv(obj_x_test['Body'], index_col = 'index')

x_test = x_test_df.values
x_test = x_test.reshape((-1,3,32,32)).transpose([0,2,3,1])
x_test = x_test.astype('float32')
x_test = x_test / 255.

# %%
# Output the labels
import numpy as np

y_test = model.predict(x_test)
y_pred = np.argmax(y_test, axis=1)

predictPdsDF = pd.DataFrame({'answer': y_pred})

predictPdsDF.to_csv("predict.csv", index = True, index_label = 'index')
